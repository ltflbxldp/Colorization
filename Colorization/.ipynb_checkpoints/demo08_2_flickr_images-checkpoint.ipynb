# %% [markdown]
# # Downloading Images using the Flickr API
#
# For many image processing problems, one needs to create a dataset of images of particular classes.  The [ImageNet site](http://www.image-net.org/) has an enormous set of images of 1000 different classes with bounding boxes.  But, this set may not have the exact image classes you are looking for.  An alternative simple way to generate image datasets is via the [Flickr API](https://stuvel.eu/flickrapi-doc/), which gives you access to millions of images in the Flickr database.
#
# In this demo, you will learn to:
# * Load images from the Flickr API
# * Resize images to a desired shape
# * Save images to a file

# %% [markdown]
# ## Installing and Loading the Flickr API package
#
# The [Flickr API](https://stuvel.eu/flickrapi-doc/) provides a simple python interface.  You will need to install it via
#
#     pip install flickrapi
#
# You can validate the installation by import the package.

# %%
import flickrapi
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import skimage.transform
import requests
from io import BytesIO

# %% [markdown]
# To use the Flickr API, you need to apply for keys.  You can do this on the [Flickr website](https://www.flickr.com/services/api/misc.api_keys.html).  Once you have the keys, they can be set as follows.

# %%
api_key = u'd41cf9eb9fb96bcb6c143ba0e6793e0d'
api_secret = u'140ed60af483e978'
flickr = flickrapi.FlickrAPI(api_key, api_secret)

# %% [markdown]
# ## Loading the Images
# The `flickr.walk()` function provides a generator of URLs for photos with a particular `keyword`.  To illustrate the method, we will get a number of elephant images.

# %%
keyword = 'sea'
dir_name = 'sea1000'
traindir_name = 'sea1000test'
photos = flickr.walk(text=keyword, tag_mode='all', tags=keyword,extras='url_c',\
                     sort='relevance',per_page=100)

# %% [markdown]
# Create a directory with the name of the keyword for the images.

# %%
import os
dir_exists = os.path.isdir(dir_name)
if not dir_exists:
    os.mkdir(dir_name)
    print("Making directory %s" % dir_name)
else:
    print("Will store images in directory %s" % dir_name)
dir_exists = os.path.isdir(dir_name)
if not dir_exists:
    os.mkdir(dir_name)
    print("Making directory %s" % dir_name)
else:
    print("Will store images in directory %s" % dir_name)
# Out:
# Making directory sea1000

# %% [markdown]
# Next, we create a routine for displaying images.

# %%
# Display the image
def disp_image(im):
    if (len(im.shape) == 2):
        # Gray scale image
        plt.imshow(im, cmap='gray')    
    else:
        # Color image.  
        im1 = (im-np.min(im))/(np.max(im)-np.min(im))*255
        im1 = im1.astype(np.uint8)
        plt.imshow(im1)    
        
    # Remove axis ticks
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# Now, we walk through the images and save the files.

# %%
import warnings
    
nimage = 1000
nt=100
i = 0
j=0
nrow = 256
ncol = 256
for photo in photos:
    url=photo.get('url_c')
    if not (url is None):
        
        # Create a file from the URL
        # This may only work in Python3
        response = requests.get(url)
        file = BytesIO(response.content)
        
        # Read image from file
        im = skimage.io.imread(file)
        
        # Resize images
        im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant')
                
        # Convert to uint8, suppress the warning about the precision loss
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            im2 = skimage.img_as_ubyte(im1)
    
        # Save the image
        local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_name,keyword, j)  
        skimage.io.imsave(local_name, im2)      
        print(local_name)
        i = i + 1        
        j = j+ 1
    if (i == nimage):
        dir_name=traindir_name
        j = 0
    if(i>= nt):
        break
# Out:
# Mountain/Mountain_0000.jpg
# Mountain/Mountain_0001.jpg
# Mountain/Mountain_0002.jpg
# Mountain/Mountain_0003.jpg
# Mountain/Mountain_0004.jpg
# Mountain/Mountain_0005.jpg
# Mountain/Mountain_0006.jpg
# Mountain/Mountain_0007.jpg
# Mountain/Mountain_0008.jpg
# Mountain/Mountain_0009.jpg
# Mountain/Mountain_0010.jpg
# Mountain/Mountain_0011.jpg
# Mountain/Mountain_0012.jpg
# Mountain/Mountain_0013.jpg
# Mountain/Mountain_0014.jpg
# Mountain/Mountain_0015.jpg
# Mountain/Mountain_0016.jpg
# Mountain/Mountain_0017.jpg
# Mountain/Mountain_0018.jpg
# Mountain/Mountain_0019.jpg
# Mountain/Mountain_0020.jpg
# Mountain/Mountain_0021.jpg
# Mountain/Mountain_0022.jpg
# Mountain/Mountain_0023.jpg
# Mountain/Mountain_0024.jpg
# Mountain/Mountain_0025.jpg
# Mountain/Mountain_0026.jpg
# Mountain/Mountain_0027.jpg
# Mountain/Mountain_0028.jpg
# Mountain/Mountain_0029.jpg
# Mountain/Mountain_0030.jpg
# Mountain/Mountain_0031.jpg
# Mountain/Mountain_0032.jpg
# Mountain/Mountain_0033.jpg
# Mountain/Mountain_0034.jpg
# Mountain/Mountain_0035.jpg
# Mountain/Mountain_0036.jpg
# Mountain/Mountain_0037.jpg
# Mountain/Mountain_0038.jpg
# Mountain/Mountain_0039.jpg
# Mountain/Mountain_0040.jpg
# Mountain/Mountain_0041.jpg
# Mountain/Mountain_0042.jpg
# Mountain/Mountain_0043.jpg
# Mountain/Mountain_0044.jpg
# Mountain/Mountain_0045.jpg
# Mountain/Mountain_0046.jpg
# Mountain/Mountain_0047.jpg
# Mountain/Mountain_0048.jpg
# Mountain/Mountain_0049.jpg
# Mountain/Mountain_0050.jpg
# Mountain/Mountain_0051.jpg
# Mountain/Mountain_0052.jpg
# Mountain/Mountain_0053.jpg
# Mountain/Mountain_0054.jpg
# Mountain/Mountain_0055.jpg
# Mountain/Mountain_0056.jpg
# Mountain/Mountain_0057.jpg
# Mountain/Mountain_0058.jpg
# Mountain/Mountain_0059.jpg
# Mountain/Mountain_0060.jpg
# Mountain/Mountain_0061.jpg
# Mountain/Mountain_0062.jpg
# Mountain/Mountain_0063.jpg
# Mountain/Mountain_0064.jpg
# Mountain/Mountain_0065.jpg
# Mountain/Mountain_0066.jpg
# Mountain/Mountain_0067.jpg
# Mountain/Mountain_0068.jpg
# Mountain/Mountain_0069.jpg
# Mountain/Mountain_0070.jpg
# Mountain/Mountain_0071.jpg
# Mountain/Mountain_0072.jpg
# Mountain/Mountain_0073.jpg
# Mountain/Mountain_0074.jpg
# Mountain/Mountain_0075.jpg
# Mountain/Mountain_0076.jpg
# Mountain/Mountain_0077.jpg
# Mountain/Mountain_0078.jpg
# Mountain/Mountain_0079.jpg
# Mountain/Mountain_0080.jpg
# Mountain/Mountain_0081.jpg
# Mountain/Mountain_0082.jpg
# Mountain/Mountain_0083.jpg
# Mountain/Mountain_0084.jpg
# Mountain/Mountain_0085.jpg
# Mountain/Mountain_0086.jpg
# Mountain/Mountain_0087.jpg
# Mountain/Mountain_0088.jpg
# Mountain/Mountain_0089.jpg
# Mountain/Mountain_0090.jpg
# Mountain/Mountain_0091.jpg
# Mountain/Mountain_0092.jpg
# Mountain/Mountain_0093.jpg
# Mountain/Mountain_0094.jpg
# Mountain/Mountain_0095.jpg
# Mountain/Mountain_0096.jpg
# Mountain/Mountain_0097.jpg
# Mountain/Mountain_0098.jpg
# Mountain/Mountain_0099.jpg
# Mountain/Mountain_0100.jpg
# Mountain/Mountain_0101.jpg
# Mountain/Mountain_0102.jpg
# Mountain/Mountain_0103.jpg
# Mountain/Mountain_0104.jpg
# Mountain/Mountain_0105.jpg
# Mountain/Mountain_0106.jpg
# Mountain/Mountain_0107.jpg
# Mountain/Mountain_0108.jpg
# Mountain/Mountain_0109.jpg
# Mountain/Mountain_0110.jpg
# Mountain/Mountain_0111.jpg
# Mountain/Mountain_0112.jpg
# Mountain/Mountain_0113.jpg
# Mountain/Mountain_0114.jpg
# Mountain/Mountain_0115.jpg
# Mountain/Mountain_0116.jpg
# Mountain/Mountain_0117.jpg
# Mountain/Mountain_0118.jpg
# Mountain/Mountain_0119.jpg
# Mountain/Mountain_0120.jpg
# Mountain/Mountain_0121.jpg
# Mountain/Mountain_0122.jpg
# Mountain/Mountain_0123.jpg
# Mountain/Mountain_0124.jpg
# Mountain/Mountain_0125.jpg
# Mountain/Mountain_0126.jpg
# Mountain/Mountain_0127.jpg
# Mountain/Mountain_0128.jpg
# Mountain/Mountain_0129.jpg
# Mountain/Mountain_0130.jpg
# Mountain/Mountain_0131.jpg
# Mountain/Mountain_0132.jpg
# Mountain/Mountain_0133.jpg
# Mountain/Mountain_0134.jpg
# Mountain/Mountain_0135.jpg
# Mountain/Mountain_0136.jpg
# Mountain/Mountain_0137.jpg
# Mountain/Mountain_0138.jpg
# Mountain/Mountain_0139.jpg
# Mountain/Mountain_0140.jpg
# Mountain/Mountain_0141.jpg
# Mountain/Mountain_0142.jpg
# Mountain/Mountain_0143.jpg
# Mountain/Mountain_0144.jpg
# Mountain/Mountain_0145.jpg
# Mountain/Mountain_0146.jpg
# Mountain/Mountain_0147.jpg
# Mountain/Mountain_0148.jpg
# Mountain/Mountain_0149.jpg
# Mountain/Mountain_0150.jpg
# Mountain/Mountain_0151.jpg
# Mountain/Mountain_0152.jpg
# Mountain/Mountain_0153.jpg
# Mountain/Mountain_0154.jpg
# Mountain/Mountain_0155.jpg
# Mountain/Mountain_0156.jpg
# Mountain/Mountain_0157.jpg
# Mountain/Mountain_0158.jpg
# Mountain/Mountain_0159.jpg
# Mountain/Mountain_0160.jpg
# Mountain/Mountain_0161.jpg
# Mountain/Mountain_0162.jpg
# Mountain/Mountain_0163.jpg
# Mountain/Mountain_0164.jpg
# Mountain/Mountain_0165.jpg
# Mountain/Mountain_0166.jpg
# Mountain/Mountain_0167.jpg
# Mountain/Mountain_0168.jpg
# Mountain/Mountain_0169.jpg
# Mountain/Mountain_0170.jpg
# Mountain/Mountain_0171.jpg
# Mountain/Mountain_0172.jpg
# Mountain/Mountain_0173.jpg
# Mountain/Mountain_0174.jpg
# Mountain/Mountain_0175.jpg
# Mountain/Mountain_0176.jpg
# Mountain/Mountain_0177.jpg
# Mountain/Mountain_0178.jpg
# Mountain/Mountain_0179.jpg
# Mountain/Mountain_0180.jpg
# Mountain/Mountain_0181.jpg
# Mountain/Mountain_0182.jpg
# Mountain/Mountain_0183.jpg
# Mountain/Mountain_0184.jpg
# Mountain/Mountain_0185.jpg
# Mountain/Mountain_0186.jpg
# Mountain/Mountain_0187.jpg
# Mountain/Mountain_0188.jpg
# Mountain/Mountain_0189.jpg
# Mountain/Mountain_0190.jpg
# Mountain/Mountain_0191.jpg
# Mountain/Mountain_0192.jpg
# Mountain/Mountain_0193.jpg
# Mountain/Mountain_0194.jpg
# Mountain/Mountain_0195.jpg
# Mountain/Mountain_0196.jpg
# Mountain/Mountain_0197.jpg
# Mountain/Mountain_0198.jpg
# Mountain/Mountain_0199.jpg
# Mountain/Mountain_0000.jpg
# Mountain/Mountain_0001.jpg
# Mountain/Mountain_0002.jpg
# Mountain/Mountain_0003.jpg
# Mountain/Mountain_0004.jpg
# Mountain/Mountain_0005.jpg
# Mountain/Mountain_0006.jpg
# Mountain/Mountain_0007.jpg
# Mountain/Mountain_0008.jpg
# Mountain/Mountain_0009.jpg
# Mountain/Mountain_0010.jpg
# Mountain/Mountain_0011.jpg
# Mountain/Mountain_0012.jpg
# Mountain/Mountain_0013.jpg
# Mountain/Mountain_0014.jpg
# Mountain/Mountain_0015.jpg
# Mountain/Mountain_0016.jpg
# Mountain/Mountain_0017.jpg
# Mountain/Mountain_0018.jpg
# Mountain/Mountain_0019.jpg
# Mountain/Mountain_0020.jpg
# Mountain/Mountain_0021.jpg
# Mountain/Mountain_0022.jpg
# Mountain/Mountain_0023.jpg
# Mountain/Mountain_0024.jpg
# Mountain/Mountain_0025.jpg
# Mountain/Mountain_0026.jpg
# Mountain/Mountain_0027.jpg
# Mountain/Mountain_0028.jpg
# Mountain/Mountain_0029.jpg
# Mountain/Mountain_0030.jpg
# Mountain/Mountain_0031.jpg
# Mountain/Mountain_0032.jpg
# Mountain/Mountain_0033.jpg
# Mountain/Mountain_0034.jpg
# Mountain/Mountain_0035.jpg
# Mountain/Mountain_0036.jpg
# Mountain/Mountain_0037.jpg
# Mountain/Mountain_0038.jpg
# Mountain/Mountain_0039.jpg
# Mountain/Mountain_0040.jpg
# Mountain/Mountain_0041.jpg
# Mountain/Mountain_0042.jpg
# Mountain/Mountain_0043.jpg
# Mountain/Mountain_0044.jpg
# Mountain/Mountain_0045.jpg
# Mountain/Mountain_0046.jpg
# Mountain/Mountain_0047.jpg
# Mountain/Mountain_0048.jpg
# Mountain/Mountain_0049.jpg
# Mountain/Mountain_0050.jpg
# Mountain/Mountain_0051.jpg
# Mountain/Mountain_0052.jpg
# Mountain/Mountain_0053.jpg
# Mountain/Mountain_0054.jpg
# Mountain/Mountain_0055.jpg
# Mountain/Mountain_0056.jpg
# Mountain/Mountain_0057.jpg
# Mountain/Mountain_0058.jpg
# Mountain/Mountain_0059.jpg
# Mountain/Mountain_0060.jpg
# Mountain/Mountain_0061.jpg
# Mountain/Mountain_0062.jpg
# Mountain/Mountain_0063.jpg
# Mountain/Mountain_0064.jpg
# Mountain/Mountain_0065.jpg
# Mountain/Mountain_0066.jpg
# Mountain/Mountain_0067.jpg
# Mountain/Mountain_0068.jpg
# Mountain/Mountain_0069.jpg
# Mountain/Mountain_0070.jpg
# Mountain/Mountain_0071.jpg
# Mountain/Mountain_0072.jpg
# Mountain/Mountain_0073.jpg
# Mountain/Mountain_0074.jpg
# Mountain/Mountain_0075.jpg
# Mountain/Mountain_0076.jpg
# Mountain/Mountain_0077.jpg
# Mountain/Mountain_0078.jpg
# Mountain/Mountain_0079.jpg
# Mountain/Mountain_0080.jpg
# Mountain/Mountain_0081.jpg
# Mountain/Mountain_0082.jpg
# Mountain/Mountain_0083.jpg
# Mountain/Mountain_0084.jpg
# Mountain/Mountain_0085.jpg
# Mountain/Mountain_0086.jpg
# Mountain/Mountain_0087.jpg
# Mountain/Mountain_0088.jpg
# Mountain/Mountain_0089.jpg
# Mountain/Mountain_0090.jpg
# Mountain/Mountain_0091.jpg
# Mountain/Mountain_0092.jpg
# Mountain/Mountain_0093.jpg
# Mountain/Mountain_0094.jpg
# Mountain/Mountain_0095.jpg
# Mountain/Mountain_0096.jpg
# Mountain/Mountain_0097.jpg
# Mountain/Mountain_0098.jpg
# Mountain/Mountain_0099.jpg

# %% [markdown]
# We plot some of the loaded images.  Some of them may be slightly distorted since the re-shaping could have changed the aspect ratio.

# %%
plt.figure(figsize=(20,20))
nplot = 4
for i in range(nplot):
    fn = '{0:s}/{1:s}_{2:04d}.jpg'.format(keyword,keyword, i)  
    im = skimage.io.imread(fn)
    plt.subplot(1,nplot,i+1)
    disp_image(im)
